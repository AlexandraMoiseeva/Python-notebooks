# %% [markdown]
# # Домашнее задание: распознавание лиц с помощью глубоких нейронных сетей
#
# В этом задании вы будете исследовать использование глубоких нейронных сетей для решения проблемы распознавания лиц. Цель заключается в обучении модели, которая способна идентифицировать людей по набору изображений лиц.
#
# ## Основные шаги
#
# 1. **Сбор данных**: Соберите набор данных изображений лиц. Вы можете использовать существующие наборы данных, такие как [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) или [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html), или создать свой собственный набор данных, используя инструменты, такие как [OpenCV](https://opencv.org/).
# 2. **Предварительная обработка данных**: Предварительно обработайте изображения, чтобы они подходили для обучения глубокой нейронной сети. Это может включать изменение размера, нормализацию и аугментацию.
# 3. **Выбор модели**: Выберите подходящую архитектуру глубокой нейронной сети для задачи распознавания лиц. Вы можете использовать заранее обученные модели, такие как [VGG Face](http://www.robots.ox.ac.uk/~vgg/software/vgg_face/) или [FaceNet](https://github.com/davidsandberg/facenet), или разработать свою собственную архитектуру.
# 4. **Обучение модели**: Обучите выбранную модель на предварительно обработанном наборе данных.
# 5. **Оценка модели**: Оцените обученную модель на тестовом наборе, чтобы измерить ее производительность. Вы можете использовать метрики, такие как точность, точность и полноту.
# 6. **Оптимизация модели**: Оптимизируйте модель для улучшения ее производительности. Это может включать настройку гиперпараметров, регуляризацию и дообучение.
# 7. **Развёртывание**: Разверните обученную модель. Это может включать интеграцию ее с веб-сервисом или мобильным приложением.

# %% [markdown]
# # Минимальные требования
#
# - Приведите демонстрацию решения в следующем виде.
#     1. На вход модели подается 1 ваше изображение и еще 15 тестовых изоражений, из которых 10 других людей и 5 ваших изображений.
#     2. Хотя бы в 6 из 10 случаев ваше решение должно определить, что на тестовых изображениях других людей изображены не вы.
#     3. Хотя бы в 3 из 5 случаев ваше решение должно определить, что на тестовых изображениях с вами изображены именно вы.
#     4. При этом не разрешается использвать в обучающей выборке ваше изображение и те 15 тестовых изорбражений.
#     5. Во время демонстрации решения предусмотрите возможность, что вас попросят загузить в демонстарцию новое 1 ваше изображение и 15 тестовых.
#
# ----

# %% [markdown]
# ## Идеи для реализации

# %% [markdown]
# - Экспериментируйте с разными архитектурами глубоких нейронных сетей и сравнивайте их производительность.
# - Экспериментируйте с Siamese Neural Networks, которые могут изучать функцию сходства между двумя изображениями и могут быть полезны для задач верификации лиц.
# - Исследуйте ArcFace loss, которые являются функцией потерь, специально разработанной для задач распознавания лиц и показала многообещающие результаты.
# - Исследуйте self-supervised learning techniques, которые могут учиться на неразмеченных данных и могут улучшить производительность модели.
# - Рассмотрите использование metric learning для изучения пространства признаков, где расстояния между изображениями соответствуют их сходству в терминах идентичности.
# - Обучите модель на крупномасштабном наборе данных, таком как MS-Celeb-1M или VGGFace2, и исследуйте влияние размера данных на производительность модели.
# - Исследуйте различные методы аугментации данных, чтобы улучшить устойчивость модели.
# - Исследуйте использование передачи обучения для обучения модели на более маленьком наборе данных.
# - Рассмотреите возможность идентификации лиц вне заданного обучающего набора данных.
# - Создайте мобильное или веб приложение, которое использует модель распознавания лиц для идентификации в режиме реального времени.
# - Обучите модель на конкретном подмножестве набора данных, таком как знаменитости или исторические личности.
#
# ----
#
# Еще несколько вариантов релизации:
#
# 1. **Вариант 1**: Используйте заранее обученную модель FaceNet для распознавания лиц в наборе данных Labeled Faces in the Wild с помощью PyTorch. Оцените производительность модели на тестовом наборе и оптимизируйте ее, используя техники дообучения и регуляризации.
# 2. **Вариант 2**: Разработайте и реализуйте собственную архитектуру глубокой нейронной сети для распознавания лиц с помощью PyTorch. Обучите модель на более маленьком наборе данных, таком как набор данных AT&T Faces, и оцените ее производительность. Экспериментируйте с различными техниками регуляризации, такими как отсев и L2-регуляризация, чтобы улучшить обобщающую способность модели.
# 3. **Вариант 3**: Обучите Siamese Neural Network с помощью PyTorch, чтобы изучить функцию сходства между двумя изображениями для задач верификации лиц. Используйте набор данных Labeled Faces in the Wild для обучения и оценки модели, и оптимизируйте ее, используя техники регуляризации и настройки гиперпараметров.
# 4. **Вариант 4**: Исследуйте потери ArcFace, функцию потерь, специально разработанную для задач распознавания лиц, с помощью PyTorch. Обучите модель, используя потери ArcFace, и сравните ее производительность с моделью, обученной с помощью традиционных потерь softmax. Оптимизируйте модель, используя техники дообучения и передачи обучения.
# 5. **Вариант 5**: Обучите модель на крупномасштабном наборе данных, таком как MS-Celeb-1M или VGGFace2, и исследуйте влияние размера данных на производительность модели. Экспериментируйте с различными методами аугментации данных, такими как поворот, трансляция и переворот, чтобы улучшить устойчивость модели.
#
# Надеюсь, эти варианты планов будут полезны! Дайте мне знать, если у вас есть какие-либо вопросы или вам нужна дополнительная помощь.

# %% [markdown]
# ## Полезные ссылки

# %% [markdown]
# - **[Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/)**: A dataset for collecting face images.
# - **[CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html)**: A dataset for collecting face images.
# - **[OpenCV](https://opencv.org/)**: A library for image processing.
# - **[VGG Face](http://www.robots.ox.ac.uk/~vgg/software/vgg_face/)**: A pre-trained model for face recognition.
# - **[FaceNet](https://github.com/davidsandberg/facenet)**: A pre-trained model for face recognition.
# - **[DeepFace](https://research.fb.com/publications/deepface-closing-the-gap-to-human-level-performance-in-face-verification/)**: A research paper on face recognition.
# - **[DeepID](https://www.cv-foundation.org/openaccess/content_cvpr_2014/papers/Sun_Deep_Identification_Using_2014_CVPR_paper.pdf)**: A research paper on face recognition.
# - **[OpenFace](https://cmusatyalab.github.io/openface/)**: An open-source face recognition toolkit.
#
# Вот несколько полезных ссылок для быстрого прототипирования мобильных приложений на Python:
#
# - [Kivy](https://kivy.org/#home): библиотека Python с открытым исходным кодом для быстрого развития приложений, которые используют инновационные пользовательские интерфейсы, такие как приложения с мультитачем.
# - [BeeWare](https://beeware.org/): набор инструментов для разработки мобильных и настольных приложений с помощью Python.
# - [Python для Android](https://github.com/kivy/python-for-android): набор инструментов для создания приложений Python для Android.
# - [PyMob](https://www.pymob.org/): платформа, которая позволяет разработчикам писать мобильные приложения на Python, которые работают нативно на устройствах Android и iOS.
#
# Вот несколько полезных ссылок для развертывания моделей PyTorch на веб-сервере:
#
# - [PyTorch Serving](https://pytorch.org/serve/): простой и гибкий способ развертывания моделей PyTorch в масштабе.
# - [FastAPI](https://fastapi.tiangolo.com/): современный, быстрый (высокопроизводительный) веб-фреймворк для создания API с помощью Python 3.6+.
# - [Flask](https://flask.palletsprojects.com/en/2.0.x/): легкий веб-фреймворк для создания веб-приложений на Python.
# - [Django](https://www.djangoproject.com/): высокоуровневый Python веб-фреймворк, который способствует быстрому развитию и чистому, прагматичному дизайну.
# - [Heroku](https://www.heroku.com/): облачная платформа, которая позволяет развертывать, управлять и масштабировать приложения, написанные на Python и других языках.

# %%
import pandas as pd
import numpy as np
import random
import cv2    
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import tensorflow as tf

from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, ZeroPadding2D, Convolution2D, MaxPooling2D, Activation, BatchNormalization
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tqdm import tqdm
from sklearn.metrics import precision_recall_curve,accuracy_score,f1_score,precision_score,recall_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
scaler = StandardScaler()
pca = PCA(n_components=128)
le = LabelEncoder()

from PIL import Image

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %%
import os
source_dir=os.path.join('105_classes_pins_dataset')

# %%
class IdentityMetadata():
    def __init__(self, base, name, file):
        self.base = base
        self.name = name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file) 
    
def load_metadata(path):
    metadata = []
    for i in os.listdir(path):
        for f in os.listdir(os.path.join(path, i)):
            ext = os.path.splitext(f)[1]
            if ext == '.jpg' or ext == '.jpeg':
                metadata.append(IdentityMetadata(path, i, f))
    return np.array(metadata)

metadata = load_metadata(source_dir)

# %%
print('metadata shape :', metadata.shape)
# Out:
# metadata shape : (17534,)

# %%
metadata = list(metadata)

# %%
final_data_first = random.sample(metadata[:213], 5)
final_data_first.extend(random.sample(metadata[213:], 10))

# %%
final_data_first
# Out:
# [105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima210_112.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima161_64.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima81_197.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima197_97.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima136_37.jpg,
#  105_classes_pins_dataset\pins_amber heard\amber heard14_254.jpg,
#  105_classes_pins_dataset\pins_Ben Affleck\Ben Affleck34_213.jpg,
#  105_classes_pins_dataset\pins_kiernen shipka\kiernen shipka92_2465.jpg,
#  105_classes_pins_dataset\pins_Krysten Ritter\Krysten Ritter20_1769.jpg,
#  105_classes_pins_dataset\pins_Maria Pedraza\Maria Pedraza30_1948.jpg,
#  105_classes_pins_dataset\pins_tom ellis\tom ellis33_4379.jpg,
#  105_classes_pins_dataset\pins_Tom Holland\Tom Holland100_4686.jpg,
#  105_classes_pins_dataset\pins_Chris Hemsworth\Chris Hemsworth63_519.jpg,
#  105_classes_pins_dataset\pins_Katharine Mcphee\Katharine Mcphee174_1581.jpg,
#  105_classes_pins_dataset\pins_Tuppence Middleton\Tuppence Middleton156_2585.jpg]

# %%
for elem in final_data_first:
    metadata.remove(elem)

# %%
metadata = np.array(metadata)

# %%
print('metadata shape :', metadata.shape)
# Out:
# metadata shape : (17519,)

# %%
def load_image(path):
    img = cv2.imread(path, 1)
    return img[...,::-1]

# %%
def vgg_face():	
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))
    
    model.add(Convolution2D(4096, (7, 7), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(4096, (1, 1), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(2622, (1, 1)))
    model.add(Flatten())
    model.add(Activation('softmax'))
    
    model.load_weights('vgg_face_weights.h5')
    return model

# %%
from pytorch_metric_learning import losses

# %%
def classifier_model(input_dim):
    classifier_model=Sequential()
    classifier_model.add(Dense(units=1024,input_dim=input_dim,kernel_initializer='glorot_uniform'))
    classifier_model.add(BatchNormalization())
    classifier_model.add(Activation('tanh'))
    classifier_model.add(Dropout(0.8))
    
    classifier_model.add(Dense(units=512,kernel_initializer='glorot_uniform'))
    classifier_model.add(BatchNormalization())
    classifier_model.add(Activation('tanh'))
    classifier_model.add(Dropout(0.4))
    
    classifier_model.add(Dense(units=256,kernel_initializer='glorot_uniform'))
    classifier_model.add(BatchNormalization())
    classifier_model.add(Activation('tanh'))
    classifier_model.add(Dropout(0.3))
    
    classifier_model.add(Dense(units=128,kernel_initializer='glorot_uniform'))
    classifier_model.add(BatchNormalization())
    classifier_model.add(Activation('tanh'))
    classifier_model.add(Dropout(0.2))
    
    classifier_model.add(Dense(units=105,kernel_initializer='he_uniform'))
    classifier_model.add(Activation('softmax'))
    
    classifier_model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(),optimizer='nadam',metrics=['accuracy'])
    
    return classifier_model

# %%
model = vgg_face()

# %%
vgg_face_descriptor = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

# %%
metadata_test = metadata[np.arange(metadata.shape[0]) % 1 == 0]

# %%
#model.summary()

# %%
embeddings = []
embeddings_ind = []

person_rep=dict()
for i, m in tqdm(enumerate(metadata_test)):
    img_path = metadata_test[i].image_path()
    img = load_image(img_path)
    img = (img / 255.).astype(np.float32)
    img = cv2.resize(img, dsize = (224,224))
    img=img_to_array(img)
    img=np.expand_dims(img,axis=0)
    img=preprocess_input(img)
    
    embedding_vector =  vgg_face_descriptor(img)
    
    embeddings.append(np.squeeze(K.eval(embedding_vector)).tolist())
    if not m.name in person_rep:
        person_rep[m.name] = len(person_rep)
    
    embeddings_ind.append(person_rep[m.name])
# Out:
# 17519it [5:34:03,  1.14s/it]

# %%
embeddings = np.array(embeddings)
embeddings_ind = np.array(embeddings_ind)

# %%
train_idx = np.arange(metadata_test.shape[0]) % 9 != 0
test_idx = np.arange(metadata_test.shape[0]) % 9 == 0

X_train = embeddings[train_idx]
X_test = embeddings[test_idx]

y_train = embeddings_ind[train_idx]
y_test = embeddings_ind[test_idx]

# %%
print(f'X_train: {type(X_train[0][0])}')
print(f'y_train: {type(y_train[0])}')
print(f'X_test: {type(X_test[0])}')
print(f'y_test: {type(y_test[0])}')
# Out:
# X_train: <class 'numpy.float64'>
# y_train: <class 'numpy.int32'>
# X_test: <class 'numpy.ndarray'>
# y_test: <class 'numpy.int32'>

# %%
print(f'X_train: {X_train.shape}')
print(f'y_train: {y_train.shape}')
print(f'X_test: {X_test.shape}')
print(f'y_test: {y_test.shape}')
# Out:
# X_train: (15572, 2622)
# y_train: (15572,)
# X_test: (1947, 2622)
# y_test: (1947,)

# %%
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
X_train_pca = pca.fit_transform(X_train_std)
X_test_pca = pca.transform(X_test_std)
y_train_encoded = le.fit_transform(y_train)
y_test_encoded = le.transform(y_test)

# %%
class_model = classifier_model(X_train_pca.shape[1])

# %%
#%%time
class_model.fit(X_train_pca, y_train_encoded, epochs=400, validation_data=(X_test_pca, y_test_encoded))
# Out:
# Epoch 1/400
# 487/487 [==============================] - 16s 26ms/step - loss: 4.7733 - accuracy: 0.0190 - val_loss: 4.4726 - val_accuracy: 0.0370
# Epoch 2/400
# 487/487 [==============================] - 11s 22ms/step - loss: 4.5044 - accuracy: 0.0326 - val_loss: 4.2723 - val_accuracy: 0.0550
# Epoch 3/400
# 487/487 [==============================] - 11s 22ms/step - loss: 4.3352 - accuracy: 0.0464 - val_loss: 4.1134 - val_accuracy: 0.0673
# Epoch 4/400
# 487/487 [==============================] - 10s 21ms/step - loss: 4.2083 - accuracy: 0.0571 - val_loss: 4.0110 - val_accuracy: 0.0883
# Epoch 5/400
# 487/487 [==============================] - 11s 22ms/step - loss: 4.1300 - accuracy: 0.0680 - val_loss: 3.9366 - val_accuracy: 0.1002
# Epoch 6/400
# 487/487 [==============================] - 10s 21ms/step - loss: 4.0595 - accuracy: 0.0792 - val_loss: 3.8966 - val_accuracy: 0.1053
# Epoch 7/400
# 487/487 [==============================] - 11s 22ms/step - loss: 4.0152 - accuracy: 0.0878 - val_loss: 3.8657 - val_accuracy: 0.1161
# Epoch 8/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.9648 - accuracy: 0.0934 - val_loss: 3.8225 - val_accuracy: 0.1222
# Epoch 9/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.9372 - accuracy: 0.0951 - val_loss: 3.8010 - val_accuracy: 0.1284
# Epoch 10/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.9013 - accuracy: 0.1065 - val_loss: 3.7897 - val_accuracy: 0.1238
# Epoch 11/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.8853 - accuracy: 0.1042 - val_loss: 3.7662 - val_accuracy: 0.1284
# Epoch 12/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.8561 - accuracy: 0.1111 - val_loss: 3.7385 - val_accuracy: 0.1500
# Epoch 13/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.8297 - accuracy: 0.1157 - val_loss: 3.7376 - val_accuracy: 0.1325
# Epoch 14/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7989 - accuracy: 0.1194 - val_loss: 3.7125 - val_accuracy: 0.1402
# Epoch 15/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7978 - accuracy: 0.1195 - val_loss: 3.6882 - val_accuracy: 0.1520
# Epoch 16/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7842 - accuracy: 0.1272 - val_loss: 3.6879 - val_accuracy: 0.1484
# Epoch 17/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7638 - accuracy: 0.1273 - val_loss: 3.6778 - val_accuracy: 0.1536
# Epoch 18/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7459 - accuracy: 0.1268 - val_loss: 3.6727 - val_accuracy: 0.1567
# Epoch 19/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7218 - accuracy: 0.1353 - val_loss: 3.6545 - val_accuracy: 0.1587
# Epoch 20/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7124 - accuracy: 0.1361 - val_loss: 3.6434 - val_accuracy: 0.1525
# Epoch 21/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.7094 - accuracy: 0.1391 - val_loss: 3.6546 - val_accuracy: 0.1567
# Epoch 22/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.6861 - accuracy: 0.1399 - val_loss: 3.6302 - val_accuracy: 0.1659
# Epoch 23/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.6937 - accuracy: 0.1428 - val_loss: 3.6259 - val_accuracy: 0.1674
# Epoch 24/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.6729 - accuracy: 0.1422 - val_loss: 3.6174 - val_accuracy: 0.1633
# Epoch 25/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.6549 - accuracy: 0.1429 - val_loss: 3.6088 - val_accuracy: 0.1654
# Epoch 26/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.6504 - accuracy: 0.1455 - val_loss: 3.6152 - val_accuracy: 0.1613
# Epoch 27/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.6446 - accuracy: 0.1487 - val_loss: 3.6056 - val_accuracy: 0.1659
# Epoch 28/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.6348 - accuracy: 0.1472 - val_loss: 3.5909 - val_accuracy: 0.1618
# Epoch 29/400
# 487/487 [==============================] - 10s 22ms/step - loss: 3.6279 - accuracy: 0.1485 - val_loss: 3.5877 - val_accuracy: 0.1685
# Epoch 30/400
# 487/487 [==============================] - 10s 22ms/step - loss: 3.6216 - accuracy: 0.1542 - val_loss: 3.5908 - val_accuracy: 0.1736
# Epoch 31/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.6104 - accuracy: 0.1560 - val_loss: 3.5807 - val_accuracy: 0.1710
# Epoch 32/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.6153 - accuracy: 0.1538 - val_loss: 3.5737 - val_accuracy: 0.1726
# Epoch 33/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.5957 - accuracy: 0.1590 - val_loss: 3.5715 - val_accuracy: 0.1772
# Epoch 34/400
# 487/487 [==============================] - 12s 24ms/step - loss: 3.5783 - accuracy: 0.1573 - val_loss: 3.5784 - val_accuracy: 0.1710
# Epoch 35/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.5765 - accuracy: 0.1613 - val_loss: 3.5711 - val_accuracy: 0.1705
# Epoch 36/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5712 - accuracy: 0.1596 - val_loss: 3.5631 - val_accuracy: 0.1736
# Epoch 37/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.5634 - accuracy: 0.1609 - val_loss: 3.5438 - val_accuracy: 0.1731
# Epoch 38/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.5561 - accuracy: 0.1602 - val_loss: 3.5472 - val_accuracy: 0.1669
# Epoch 39/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5615 - accuracy: 0.1634 - val_loss: 3.5523 - val_accuracy: 0.1700
# Epoch 40/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5489 - accuracy: 0.1624 - val_loss: 3.5422 - val_accuracy: 0.1731
# Epoch 41/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5290 - accuracy: 0.1710 - val_loss: 3.5489 - val_accuracy: 0.1741
# Epoch 42/400
# 487/487 [==============================] - 12s 24ms/step - loss: 3.5296 - accuracy: 0.1686 - val_loss: 3.5435 - val_accuracy: 0.1741
# Epoch 43/400
# 487/487 [==============================] - 12s 24ms/step - loss: 3.5318 - accuracy: 0.1663 - val_loss: 3.5349 - val_accuracy: 0.1700
# Epoch 44/400
# 487/487 [==============================] - 12s 24ms/step - loss: 3.5147 - accuracy: 0.1668 - val_loss: 3.5401 - val_accuracy: 0.1741
# Epoch 45/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5112 - accuracy: 0.1708 - val_loss: 3.5295 - val_accuracy: 0.1813
# Epoch 46/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.5106 - accuracy: 0.1713 - val_loss: 3.5300 - val_accuracy: 0.1828
# Epoch 47/400
# 487/487 [==============================] - 12s 24ms/step - loss: 3.4904 - accuracy: 0.1750 - val_loss: 3.5223 - val_accuracy: 0.1782
# Epoch 48/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.4990 - accuracy: 0.1752 - val_loss: 3.5188 - val_accuracy: 0.1762
# Epoch 49/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.4955 - accuracy: 0.1722 - val_loss: 3.5180 - val_accuracy: 0.1751
# Epoch 50/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.4800 - accuracy: 0.1776 - val_loss: 3.5138 - val_accuracy: 0.1818
# Epoch 51/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.4745 - accuracy: 0.1761 - val_loss: 3.5061 - val_accuracy: 0.1823
# Epoch 52/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4760 - accuracy: 0.1769 - val_loss: 3.5084 - val_accuracy: 0.1782
# Epoch 53/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4761 - accuracy: 0.1783 - val_loss: 3.5112 - val_accuracy: 0.1803
# Epoch 54/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.4592 - accuracy: 0.1772 - val_loss: 3.5058 - val_accuracy: 0.1813
# Epoch 55/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4639 - accuracy: 0.1813 - val_loss: 3.5086 - val_accuracy: 0.1900
# Epoch 56/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4450 - accuracy: 0.1832 - val_loss: 3.5009 - val_accuracy: 0.1844
# Epoch 57/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4476 - accuracy: 0.1836 - val_loss: 3.5038 - val_accuracy: 0.1859
# Epoch 58/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4526 - accuracy: 0.1796 - val_loss: 3.4895 - val_accuracy: 0.1854
# Epoch 59/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4435 - accuracy: 0.1813 - val_loss: 3.4915 - val_accuracy: 0.1849
# Epoch 60/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4360 - accuracy: 0.1844 - val_loss: 3.4866 - val_accuracy: 0.1890
# Epoch 61/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4249 - accuracy: 0.1878 - val_loss: 3.4877 - val_accuracy: 0.1962
# Epoch 62/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4142 - accuracy: 0.1871 - val_loss: 3.4910 - val_accuracy: 0.1916
# Epoch 63/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4163 - accuracy: 0.1870 - val_loss: 3.4811 - val_accuracy: 0.1921
# Epoch 64/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4145 - accuracy: 0.1917 - val_loss: 3.4869 - val_accuracy: 0.1870
# Epoch 65/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4146 - accuracy: 0.1896 - val_loss: 3.4780 - val_accuracy: 0.1859
# Epoch 66/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4074 - accuracy: 0.1867 - val_loss: 3.4746 - val_accuracy: 0.1947
# Epoch 67/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.4026 - accuracy: 0.1881 - val_loss: 3.4738 - val_accuracy: 0.1936
# Epoch 68/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3847 - accuracy: 0.1889 - val_loss: 3.4787 - val_accuracy: 0.1839
# Epoch 69/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3935 - accuracy: 0.1927 - val_loss: 3.4709 - val_accuracy: 0.1900
# Epoch 70/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3782 - accuracy: 0.1985 - val_loss: 3.4662 - val_accuracy: 0.1926
# Epoch 71/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.3734 - accuracy: 0.1988 - val_loss: 3.4715 - val_accuracy: 0.1977
# Epoch 72/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.3818 - accuracy: 0.1905 - val_loss: 3.4733 - val_accuracy: 0.1813
# Epoch 73/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.3642 - accuracy: 0.1936 - val_loss: 3.4657 - val_accuracy: 0.1875
# Epoch 74/400
# 487/487 [==============================] - 10s 21ms/step - loss: 3.3698 - accuracy: 0.1919 - val_loss: 3.4661 - val_accuracy: 0.1818
# Epoch 75/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3548 - accuracy: 0.1949 - val_loss: 3.4628 - val_accuracy: 0.1870
# Epoch 76/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3464 - accuracy: 0.1971 - val_loss: 3.4601 - val_accuracy: 0.1967
# Epoch 77/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3546 - accuracy: 0.1979 - val_loss: 3.4580 - val_accuracy: 0.1859
# Epoch 78/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.3502 - accuracy: 0.2035 - val_loss: 3.4595 - val_accuracy: 0.1926
# Epoch 79/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3367 - accuracy: 0.1970 - val_loss: 3.4571 - val_accuracy: 0.1983
# Epoch 80/400
# 487/487 [==============================] - 11s 23ms/step - loss: 3.3418 - accuracy: 0.1988 - val_loss: 3.4600 - val_accuracy: 0.1921
# Epoch 81/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3235 - accuracy: 0.2033 - val_loss: 3.4590 - val_accuracy: 0.1900
# Epoch 82/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3399 - accuracy: 0.2004 - val_loss: 3.4547 - val_accuracy: 0.1967
# Epoch 83/400
# 487/487 [==============================] - 10s 22ms/step - loss: 3.3347 - accuracy: 0.2011 - val_loss: 3.4447 - val_accuracy: 0.1983
# Epoch 84/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3275 - accuracy: 0.2045 - val_loss: 3.4460 - val_accuracy: 0.1926
# Epoch 85/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3202 - accuracy: 0.2019 - val_loss: 3.4554 - val_accuracy: 0.1926
# Epoch 86/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3093 - accuracy: 0.2009 - val_loss: 3.4523 - val_accuracy: 0.1977
# Epoch 87/400
# 487/487 [==============================] - 11s 22ms/step - loss: 3.3166 - accuracy: 0.2041 - val_loss: 3.4421 - val_accuracy: 0.1916
# Epoch 88/400
# 243/487 [=============>................] - ETA: 5s - loss: 3.2716 - accuracy: 0.2137

# %%
final_data_first
# Out:
# [105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima210_112.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima161_64.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima81_197.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima197_97.jpg,
#  105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima136_37.jpg,
#  105_classes_pins_dataset\pins_amber heard\amber heard14_254.jpg,
#  105_classes_pins_dataset\pins_Ben Affleck\Ben Affleck34_213.jpg,
#  105_classes_pins_dataset\pins_kiernen shipka\kiernen shipka92_2465.jpg,
#  105_classes_pins_dataset\pins_Krysten Ritter\Krysten Ritter20_1769.jpg,
#  105_classes_pins_dataset\pins_Maria Pedraza\Maria Pedraza30_1948.jpg,
#  105_classes_pins_dataset\pins_tom ellis\tom ellis33_4379.jpg,
#  105_classes_pins_dataset\pins_Tom Holland\Tom Holland100_4686.jpg,
#  105_classes_pins_dataset\pins_Chris Hemsworth\Chris Hemsworth63_519.jpg,
#  105_classes_pins_dataset\pins_Katharine Mcphee\Katharine Mcphee174_1581.jpg,
#  105_classes_pins_dataset\pins_Tuppence Middleton\Tuppence Middleton156_2585.jpg]

# %%
res = []
for elem in final_data_first:
    res.append(person_rep[elem.name])

# %%
for elem in final_data_first:
    print(f'{person_rep[elem.name]}, ', end = '')
# Out:
# 0, 0, 0, 0, 0, 6, 13, 55, 56, 65, 95, 98, 21, 52, 99,

# %%
persons_in_img = []
final_img = []
for (i,m) in enumerate(final_data_first):
    print(final_data_first[i])
    img_path = final_data_first[i].image_path()
    img = load_image(img_path)
    img = (img / 255.).astype(np.float32)
    img = cv2.resize(img, dsize = (224,224))
    img = np.expand_dims(img, axis=0)
    img=preprocess_input(img)
    
    img_encode=vgg_face_descriptor(img)
    img_std = np.squeeze(K.eval(img_encode))
    final_img.append(img_std)
    
final_img = np.array(final_img)
final_img = scaler.transform(final_img) 
final_img = pca.transform(final_img) 


person=class_model.predict(final_img)
person = [np.argmax(p) for p in person]
# Out:
# 105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima210_112.jpg
# 105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima161_64.jpg
# 105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima81_197.jpg
# 105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima197_97.jpg
# 105_classes_pins_dataset\pins_Adriana Lima\Adriana Lima136_37.jpg
# 105_classes_pins_dataset\pins_amber heard\amber heard14_254.jpg
# 105_classes_pins_dataset\pins_Ben Affleck\Ben Affleck34_213.jpg
# 105_classes_pins_dataset\pins_kiernen shipka\kiernen shipka92_2465.jpg
# 105_classes_pins_dataset\pins_Krysten Ritter\Krysten Ritter20_1769.jpg
# 105_classes_pins_dataset\pins_Maria Pedraza\Maria Pedraza30_1948.jpg
# 105_classes_pins_dataset\pins_tom ellis\tom ellis33_4379.jpg
# 105_classes_pins_dataset\pins_Tom Holland\Tom Holland100_4686.jpg
# 105_classes_pins_dataset\pins_Chris Hemsworth\Chris Hemsworth63_519.jpg
# 105_classes_pins_dataset\pins_Katharine Mcphee\Katharine Mcphee174_1581.jpg
# 105_classes_pins_dataset\pins_Tuppence Middleton\Tuppence Middleton156_2585.jpg
# 1/1 [==============================] - 1s 661ms/step

# %%
person
# Out:
# [5, 75, 0, 91, 26, 84, 13, 55, 56, 95, 81, 98, 21, 30, 63]

# %%
pred = []
for e in person:
    pred.append(list(person_rep.keys())[list(person_rep.values()).index(e)])

# %%
res
# Out:
# [0, 0, 0, 0, 0, 6, 13, 55, 56, 65, 95, 98, 21, 52, 99]

# %%
for i in range(15):
    plt.figure(figsize=(8,3))
    plt.suptitle(f'Фото {final_data_first[i].name}/Предсказание {pred[i]}')
    plt.subplot(121)
    first_path = os.path.join(source_dir, pred[i], os.listdir(os.path.join(source_dir, pred[i]))[0])
    second_path = final_data_first[i].image_path()
    plt.imshow(load_image(second_path))
    plt.subplot(122)
    plt.imshow(load_image(first_path))
    plt.show()

# %%
model.save('model.keras')
